# %%
import pandas as pd
import plotly.express as px

# %%
df=pd.read_csv("time_series_data.csv")
print(df.head(4))
# Out:
#          Date       Sales      Profit
# 0  2020-01-01  224.835708  147.959445
# 1  2020-01-02  193.086785  145.513562
# 2  2020-01-03  232.384427  121.022656
# 3  2020-01-04  276.151493  158.558345

# %%
df.tail(3)

# %%
fig=px.line(df,x='Date',y='Sales',title='Sales Over Time')
fig.show()

# %%
fig=px.line(df,x='Date',y=['Sales','Profit'],title='Sales Over Time')
fig.show()

# %%
fig=px.line(df,x='Date',y=['Sales','Profit'],title='Sales Over Time')
fig.update_layout(xaxis_title='Date',
                  yaxis_title='Amoount($)',
                  legend_title='Metrics',
                  xaxis_rangeslider_visible=True)
fig.show()

# %%
fig.update_traces(mode='lines+markers', hoverinfo='all')
fig.show()
